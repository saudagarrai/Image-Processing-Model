# %%
# !pip install keras
# !pip install tensorflow

# %%
import tensorflow as tf
from tensorflow.keras import utils
from tensorflow.keras.datasets import mnist 
import numpy as np
import keras
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:From C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# the data, shuffled and split between train and test sets 
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1]*X_train.shape[2]) 
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2])

# %%
print("Number of training examples :", X_train.shape[0], "and each image is of shape (%d)"%(X_train.shape[1]))
print("Number of test examples :", X_test.shape[0], "and each image is of shape (%d)"%(X_test.shape[1]))
# Out:
# Number of training examples : 60000 and each image is of shape (784)
# Number of test examples : 10000 and each image is of shape (784)

# %%
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
X_train = X_train/255
X_test = X_test/255

# %%
import keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Activation, Dropout

# %%
output_dim = 10
input_dim = X_train.shape[1]

batch_size = 128 
nb_epoch = 5

# %%
def question():
    model = Sequential()
    model.add(Dense(128, activation='sigmoid', input_shape=(input_dim,)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='tanh'))
    model.add(Dropout(0.4))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(16, activation='selu'))
    model.add(Dense(10, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.SGD(),metrics=['accuracy'])
    model.fit(X_train, y_train, batch_size=32, epochs=5,verbose=1,validation_data=(X_test, y_test))
    score = model.evaluate(X_test, y_test, verbose=0)
    return score[1]

# %%
res1 = np.zeros(10)
for i in range(10):
    res1[i] = question()
np.mean(res1)
# Out:
# WARNING:tensorflow:From C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.2238 - accuracy: 0.1644 - val_loss: 1.7239 - val_accuracy: 0.3775
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.6253 - accuracy: 0.3902 - val_loss: 0.9977 - val_accuracy: 0.6473
# ...

# %%
def question2():
    model2 = Sequential()
    model2.add(Dense(128, activation='sigmoid', input_shape=(input_dim,)))
    model2.add(Dropout(0.5))
    model2.add(Dense(64, activation='tanh'))
    model2.add(Dropout(0.4))
    model2.add(Dense(32, activation='relu'))
    model2.add(Dropout(0.3))
    model2.add(Dense(16, activation='selu'))
    model2.add(Dropout(0.1))
    model2.add(Dense(10, activation='softmax'))
    model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adam(),metrics=['accuracy'])
    model2.fit(X_train, y_train, batch_size=32, epochs=5,verbose=1,validation_data=(X_test, y_test))
    score = model2.evaluate(X_test, y_test, verbose=0)
    return score[1]

# %%
res2 = np.zeros(10)
for i in range(10):
    res2[i] = question2()
np.mean(res2)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.9033 - accuracy: 0.6991 - val_loss: 0.2887 - val_accuracy: 0.9193
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4364 - accuracy: 0.8782 - val_loss: 0.2135 - val_accuracy: 0.9388
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3506 - accuracy: 0.9043 - val_loss: 0.1789 - val_accuracy: 0.9499
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3099 - accuracy: 0.9163 - val_loss: 0.1603 - val_accuracy: 0.9553
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2776 - accuracy: 0.9240 - val_loss: 0.1445 - val_accuracy: 0.9625
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.8558 - accuracy: 0.7179 - val_loss: 0.2786 - val_accuracy: 0.9206
# Epoch 2/5
# ...

# %%
def question3():
    model3 = Sequential()
    model3.add(Dense(128, activation='sigmoid', input_shape=(input_dim,)))
    model3.add(Dropout(0.5))
    model3.add(Dense(64, activation='tanh'))
    model3.add(Dropout(0.4))
    model3.add(Dense(32, activation='relu'))
    model3.add(Dropout(0.3))
    model3.add(Dense(16, activation='selu'))
    model3.add(Dropout(0.1))
    model3.add(Dense(10, activation='softmax'))
    model3.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.AdamW(),metrics=['accuracy'])
    model3.fit(X_train, y_train, batch_size=32, epochs=5,verbose=1,validation_data=(X_test, y_test))
    score = model3.evaluate(X_test, y_test, verbose=0)
    return score[1]

# %%
res3 = np.zeros(10)
for i in range(10):
    res3[i] = question3()
np.mean(res3)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.9052 - accuracy: 0.6979 - val_loss: 0.2974 - val_accuracy: 0.9164
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4457 - accuracy: 0.8740 - val_loss: 0.2111 - val_accuracy: 0.9407
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3578 - accuracy: 0.9006 - val_loss: 0.1813 - val_accuracy: 0.9488
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3111 - accuracy: 0.9145 - val_loss: 0.1686 - val_accuracy: 0.9535
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2854 - accuracy: 0.9226 - val_loss: 0.1575 - val_accuracy: 0.9571
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.8990 - accuracy: 0.7012 - val_loss: 0.2933 - val_accuracy: 0.9182
# Epoch 2/5
# ...

# %%
def question4():
    model4 = Sequential()
    model4.add(Dense(128, activation='sigmoid', input_shape=(input_dim,)))
    model4.add(Dropout(0.5))
    model4.add(Dense(64, activation='tanh'))
    model4.add(Dropout(0.4))
    model4.add(Dense(32, activation='relu'))
    model4.add(Dropout(0.3))
    model4.add(Dense(16, activation='selu'))
    model4.add(Dropout(0.1))
    model4.add(Dense(10, activation='softmax'))
    model4.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Nadam(),metrics=['accuracy'])
    model4.fit(X_train, y_train, batch_size=32, epochs=5,verbose=1,validation_data=(X_test, y_test))
    score = model4.evaluate(X_test, y_test, verbose=0)
    return score[1]

# %%
res4 = np.zeros(10)
for i in range(10):
    res4[i] = question4()
np.mean(res4)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.9030 - accuracy: 0.6950 - val_loss: 0.3035 - val_accuracy: 0.9152
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4418 - accuracy: 0.8767 - val_loss: 0.2144 - val_accuracy: 0.9397
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3543 - accuracy: 0.9028 - val_loss: 0.1780 - val_accuracy: 0.9479
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3077 - accuracy: 0.9165 - val_loss: 0.1555 - val_accuracy: 0.9555
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2814 - accuracy: 0.9241 - val_loss: 0.1478 - val_accuracy: 0.9590
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.8953 - accuracy: 0.7062 - val_loss: 0.2836 - val_accuracy: 0.9203
# Epoch 2/5
# ...

# %%
# !pip install tensorflow
# !pip install keras-tuner
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ------------------------------------ 128.9/128.9 kB 847.7 kB/s eta 0:00:00
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
from tensorflow.keras.datasets import mnist
 


(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Flatten(input_shape=(28, 28)))
    
    hp_units = hp.Int('units', min_value=250, max_value=260, step=2)
    model.add(layers.Dense(units=hp_units, activation='sigmoid'))
    model.add(layers.Dense(16, activation='tanh'))
    model.add(layers.Dense(8, activation='relu'))
    model.add(layers.Dense(4, activation='selu'))
    model.add(layers.Dense(10, activation='softmax'))
   
    hp_learning_rate = hp.Choice('learning_rate', values=[0.1, 0.01, 0.15])
    hp_batch_size = hp.Choice('batch_size', values=[4, 8, 16])
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=hp_learning_rate),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=1,
    directory='keras_tuner_dir',
    project_name='mnist_tuning')

tuner.search(x_train, y_train,
             epochs=5,
             validation_data=(x_test, y_test))

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

model = tuner.hypermodel.build(best_hps)

model.fit(x_train, y_train,
          epochs=10,
          batch_size=best_hps.get('batch_size'),
          validation_data=(x_test, y_test))

eval_result = model.evaluate(x_test, y_test)
print("Test loss:", eval_result[0])
print("Test accuracy:", eval_result[1])
# Out:
# Trial 5 Complete [00h 00m 24s]
# val_accuracy: 0.9469000101089478
#
# Best val_accuracy So Far: 0.9577999711036682
# Total elapsed time: 00h 02m 01s
# Epoch 1/10
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.7511 - accuracy: 0.7519 - val_loss: 0.2813 - val_accuracy: 0.9245
# Epoch 2/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.2535 - accuracy: 0.9319 - val_loss: 0.2726 - val_accuracy: 0.9302
# Epoch 3/10
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.1798 - accuracy: 0.9516 - val_loss: 0.1647 - val_accuracy: 0.9556
# Epoch 4/10
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.1399 - accuracy: 0.9620 - val_loss: 0.1491 - val_accuracy: 0.9609
# Epoch 5/10
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.1149 - accuracy: 0.9686 - val_loss: 0.1400 - val_accuracy: 0.9653
# Epoch 6/10
# ...
